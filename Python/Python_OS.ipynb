# %%
#file management in python using os library

#using import command we can import or include the required library in our
#python program

#import libraryname

import os  #os : operating system

# %%
#change directory (directory is nothing but folder)

os.chdir('D:\\ashwath\\ns_trainings\\mystuff')

# %%
os.getcwd() #get current working directory

# %%
#to see the list of files and folders in the current directory
os.listdir()

# %%
#to create new directory, first
#ensure that we are at the proper folder/directory if yes 
#then create new directory, else pls change the path to the required
#path where u need to create the directory
os.chdir('D:\\ashwath\\ns_trainings')
os.getcwd()

# %%
os.listdir()

# %%
#(make directory/folder : mkdir)
#creates a new folder/directory in the current path
os.mkdir("BoomiNeha")

# %%
os.listdir()

# %%
os.getcwd()

# %%
#to change the path to pythonAIBatch
os.chdir('D:\\ashwath\\ns_trainings\\boomineha')
os.getcwd()

# %%
os.listdir()

# %%
os.chdir('D:\\ashwath\\ns_trainings')
print(os.getcwd())
#print(os.listdir())
#os.listdir()

# %%
#renaming a directory
#rename : chaning the name of existing directory or file
# os.getcwd()
# os.chdir('D:\\ashwath\\ns_trainings\\mystuff')
os.getcwd()
os.rename("boomineha","boomikaneha")

# %%
os.listdir()

# %%
os.getcwd()
# os.chdir('D:\\ashwath\\ns_trainings')
# os.getcwd()         
# #os.listdir()

# %%
#removing directory
os.getcwd()
os.rmdir("boomikaneha")  #rmdir : remove directory

# %%
os.listdir()

# %%
#creating the directory:
os.getcwd()
os.mkdir("NewDir")
os.chdir('D:\\ashwath\\ns_trainings\\newdir')
os.getcwd()

# %%
#to check any files in the directory
print(os.getcwd())
os.listdir()

# %%
#removing a file
os.chdir('D:\\ashwath\\ns_trainings')
os.getcwd()
