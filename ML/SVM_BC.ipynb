# %%
#breast cancer classification using SVM :

from sklearn import datasets

#Load dataset
cancer = datasets.load_breast_cancer()

# %%
print(cancer)

# %%
# print the names of the 30 features
print("Features: ", cancer.feature_names)

# print the label type of cancer('malignant' 'benign')
print("Labels: ", cancer.target_names)

# %%
# print data(feature)shape
cancer.data.shape

# %%
# print the cancer data features (top 5 records)
print(cancer.data[0:5])

# %%
# print the cancer labels (0:malignant, 1:benign)
print(cancer.target)

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(cancer.data,cancer.target, test_size=0.3,random_state=109) # 70% training and 30% test

# %%
#Import svm model
from sklearn import svm

#Create a svm Classifier
#clf = svm.SVC(kernel = 'linear') # Linear Kernel

clf = svm.SVC(kernel = 'poly') # polynominal kernal
#clf = svm.SVC(kernel = 'rbf') # radial bais function
#clf = svm.SVC(kernel = 'sigmoid') # sigmoid kernal
#Train the model using the training sets
clf.fit(X_train, y_train)

ycap = clf.predict(X_train)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_train, ycap)*100)

# %%
#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Model Accuracy: for test data
print("Accuracy:",metrics.accuracy_score(y_test, y_pred)*100)

# %%
# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(y_test, y_pred)*100)

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(y_test, y_pred)*100)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# confusion matrix
matrix = confusion_matrix(y_test, y_pred)
print('Confusion matrix : \n',matrix)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
model=DecisionTreeClassifier()
model.fit(X_train,y_train)
dtycap=model.predict(X_train)
dtacc=accuracy_score(y_train,ycap)

print("Accuracy of Decision Tree : ",dtacc*100)

# %%
dtest=model.predict(X_test)
dtacc1=accuracy_score(y_test,dtest)

print("Accuracy of Decision Tree : ",dtacc1*100)

# %%
# confusion matrix
matrix = confusion_matrix(y_test, dtest)
print('Confusion matrix : \n',matrix)
